# %% [markdown]
# <a href="https://colab.research.google.com/github/Mcbryan11/Project/blob/main/Crawling%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crawling Data 19/03/2023

# %%
import pandas as pd
import numpy as np
import tweepy
import csv
import re

# menghitung sentimen kata-kata yang berbahasa inggris
from textblob import TextBlob
from datetime import datetime
access_token ="258199811-llOno7xx7uvYJuoGQNvrXAtHsgeeDJDQRDhCZb0Y"
access_token_secret ="bD4LwtQ2OtmBuKCnTXR4A5HQYTqqWH3IWEhbAfHrysBax"
api_key ="oTozcNGFucJwfqL6TEfqQtaWi"
api_key_secret ="6cRNX3IHJIStqfWGdcv2PMM6B625VLaDxk34vM3BT9EpIsHKje"

auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# #### 1. Keyword Syiah

# %%
since_date = datetime.strptime('2023-03-19', '%Y-%m-%d')
last_tweet1 = api.search_tweets(q='syiah', lang='id', count=1, until='2023-03-28')

last_tweet_id1 = last_tweet1[0].id if len(last_tweet1) > 0 else None
twit1 = api.search_tweets(q='syiah', lang='id', count=100, since_id=last_tweet_id1)


hasilSearch1 = twit1
hasilSearch = hasilSearch1
hasilAnalisis = []


for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih =' ' .join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", tweet.text).split())
    hasilAnalisis.append(tweet_properties)

tanggal_tweet=[]
pengguna=[]
tweet=[]


for i in range (0,len (hasilAnalisis)):
    pengguna.append (hasilAnalisis [i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

maret_syiah = pd.DataFrame({'pengguna' :pengguna, 'tweet': tweet})

# %%
maret_syiah
# Out:
#            pengguna                                              tweet
# 0        towongsing  RT @pengarang_sajak: Adakah simpati utk anak2 ...
# 1           fhyetan  @Nebuchanedzar_I @mudasir_11 @UpdateBolabola G...
# 2        MHHBJA2005  Genap 8 tahun buat serangan pencerobohan ke at...
# 3       HarryRusuh2  @NdaJoesh @HarryRidwan__Ay Mudah mudahan. Tera...
# 4      ahmaddiontri  @andy24670125 @fadlizon Wkwkwk, padahal Saudi ...
# ..              ...                                                ...
# 95     AliefMohamad  @Terasing Sekali lagi tanya dan terakhir, mana...
# 96   ainunnnajibbbb  @Iwanak8 @_esjerukpanas @tanyakanrl Ada buktin...
# 97        najmirais                      @idzhamnabil_ Ajad join syiah
# 98     daulatbagong  @andiakb20229199 @publictome @dhadhahar @hamka...
# 99  MOSLEMSOLIDARI1  @kuatkuatan @putrapetir_007 @islah_bahrawi Bet...
#
# [100 rows x 2 columns]

# %% [markdown]
# #### 2. Keyword Syiah Indonesia

# %%
since_date = datetime.strptime('2023-03-19', '%Y-%m-%d')

last_tweet2 = api.search_tweets(q='syiah indonesia', lang='id', count=1, until='2023-03-28')
last_tweet_id2 = last_tweet2[0].id if len(last_tweet2) > 0 else None
twit2 = api.search_tweets(q='syiah indonesia', lang='id', count=100, since_id=last_tweet_id2)

hasilSearch2 = twit2
hasilSearch = hasilSearch2
hasilAnalisis = []


for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih =' ' .join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", tweet.text).split())
    hasilAnalisis.append(tweet_properties)

pengguna=[]
tweet=[]


for i in range (0,len (hasilAnalisis)):
    pengguna.append (hasilAnalisis [i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

maret_syiah_indonesia = pd.DataFrame({'pengguna' :pengguna, 'tweet': tweet})

# %%
maret_syiah_indonesia
# Out:
#            pengguna                                              tweet
# 0        Bengkel_MP  RT @infoahlulbait: Bulan Ramadhan, Kesempatan ...
# 1        Bengkel_MP  RT @infoahlulbait: Imam Ali Zainal Abidin dan ...
# 2        Bengkel_MP  RT @maulatv: 🎦 Ini Adalah Istiqomah - https://...
# 3        Bengkel_MP  RT @infoahlulbait: Imam Ali bin Abi Thalib as ...
# 4        Bengkel_MP  RT @infoahlulbait: Doa Hari Ke-6 Ramadhan\n\n#...
# 5           Keboth3  RT @maulatv: 🎦 Doa Harian Bulan Ramadhan [Hari...
# 6           Keboth3  RT @maulatv: 🎦 Ini Adalah Istiqomah - https://...
# 7           Keboth3  RT @infoahlulbait: Doa Hari Ke-6 Ramadhan\n\n#...
# 8           Keboth3  RT @infoahlulbait: Imam Ali bin Abi Thalib as ...
# 9           Keboth3  RT @infoahlulbait: Imam Ali Zainal Abidin dan ...
# 10          Keboth3  RT @infoahlulbait: Bulan Ramadhan, Kesempatan ...
# 11       Haura_saja  RT @maulatv: 🎦 Ini Adalah Istiqomah - https://...
# ...

# %% [markdown]
# #### 3. Keyword Syiah Kafir

# %%
since_date = datetime.strptime('2023-03-19', '%Y-%m-%d')

last_tweet3 = api.search_tweets(q='syiah kafir', lang='id', count=1, until='2023-03-28')
last_tweet_id3 = last_tweet3[0].id if len(last_tweet3) > 0 else None
twit3 = api.search_tweets(q='syiah kafir', lang='id', count=100, since_id=last_tweet_id3)

hasilSearch3 = twit3
hasilSearch = hasilSearch3
hasilAnalisis = []


for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih =' ' .join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", tweet.text).split())
    hasilAnalisis.append(tweet_properties)

pengguna=[]
tweet=[]


for i in range (0,len (hasilAnalisis)):
    pengguna.append (hasilAnalisis [i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

maret_syiah_kafir = pd.DataFrame({'pengguna' :pengguna, 'tweet': tweet})

# %%
maret_syiah_kafir
# Out:
#      pengguna                                              tweet
# 0    Terasing  @AliefMohamad Ada kenyataan dari Mesir menyata...
# 1  he39861400  @islah_bahrawi Syiah B4hr4wi sedang memolitisa...

# %% [markdown]
# #### 4. Keyword Syiah Sesat

# %%
since_date = datetime.strptime('2023-03-19', '%Y-%m-%d')

last_tweet4 = api.search_tweets(q='syiah sesat', lang='id', count=1, until='2023-03-28')
last_tweet_id4 = last_tweet4[0].id if len(last_tweet4) > 0 else None
twit4 = api.search_tweets(q='syiah sesat', lang='id', count=100, since_id=last_tweet_id4)

hasilSearch4 = twit4
hasilSearch = hasilSearch4
hasilAnalisis = []


for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih =' ' .join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", tweet.text).split())
    hasilAnalisis.append(tweet_properties)

pengguna=[]
tweet=[]


for i in range (0,len (hasilAnalisis)):
    pengguna.append (hasilAnalisis [i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

maret_syiah_sesat = pd.DataFrame({'pengguna' :pengguna, 'tweet': tweet})

# %%
maret_syiah_sesat
# Out:
#        pengguna                                              tweet
# 0     Fariz1205  @Salim_Iskandar @kismath90 Sekor syiah sesat ,...
# 1      Terasing  @AliefMohamad Ada kenyataan dari Mesir menyata...
# 2      Terasing  @AliefMohamad Ada ka Kenyataan Mufti Mesir bah...
# 3  AliefMohamad  @Terasing Kalau tidak sesat, mengapa perlu dik...
# 4  AliefMohamad  @Terasing Kesian , tak faham melayu. Orang tan...
# 5   alhaqcentre  BAHAYA SYIAH MEMANIPULASIKAN PEMIKIRAN UMAT IS...
# 6      Terasing  @AliefMohamad Perbuatan menyebar itu  isu dan ...

# %% [markdown]
# #### 5. Keyword Syiah Diluar Islam

# %%
since_date = datetime.strptime('2023-03-19', '%Y-%m-%d')

last_tweet5 = api.search_tweets(q='syiah diluar islam', lang='id', count=1, until='2023-03-28')
last_tweet_id5 = last_tweet5[0].id if len(last_tweet5) > 0 else None
twit5 = api.search_tweets(q='syiah diluar islam', lang='id', count=100, since_id=last_tweet_id5)

hasilSearch5 = twit5
hasilSearch = hasilSearch5
hasilAnalisis = []


for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih =' ' .join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", tweet.text).split())
    hasilAnalisis.append(tweet_properties)

pengguna=[]
tweet=[]


for i in range (0,len (hasilAnalisis)):
    pengguna.append (hasilAnalisis [i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

maret_syiah_diluar_islam = pd.DataFrame({'pengguna' :pengguna, 'tweet': tweet})

# %%
maret_syiah_diluar_islam
# Out:
# Empty DataFrame
# Columns: [pengguna, tweet]
# Index: []

# %% [markdown]
# #### 6. Keyword Syiah Islam

# %%
since_date = datetime.strptime('2023-03-19', '%Y-%m-%d')

last_tweet6 = api.search_tweets(q='syiah islam', lang='id', count=1, until='2023-03-28')
last_tweet_id6 = last_tweet6[0].id if len(last_tweet6) > 0 else None
twit6 = api.search_tweets(q='syiah islam', lang='id', count=100, since_id=last_tweet_id6)

hasilSearch6 = twit6
hasilSearch = hasilSearch6
hasilAnalisis = []


for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih =' ' .join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", tweet.text).split())
    hasilAnalisis.append(tweet_properties)

pengguna=[]
tweet=[]


for i in range (0,len (hasilAnalisis)):
    pengguna.append (hasilAnalisis [i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

maret_syiah_islam = pd.DataFrame({'pengguna' :pengguna, 'tweet': tweet})

# %%
maret_syiah_islam
# Out:
#         pengguna                                              tweet
# 0        fhyetan  @Nebuchanedzar_I @mudasir_11 @UpdateBolabola G...
# 1     MHHBJA2005  Genap 8 tahun buat serangan pencerobohan ke at...
# 2     Bengkel_MP  RT @infoahlulbait: Bulan Ramadhan, Kesempatan ...
# 3     Bengkel_MP  RT @infoahlulbait: Imam Ali Zainal Abidin dan ...
# 4     Bengkel_MP  RT @infoahlulbait: Imam Ali bin Abi Thalib as ...
# ..           ...                                                ...
# 95       akukash  RT @abuhafiz1: Masuk kedalam Kaabah adalah pel...
# 96  hajardottcom  RT @abuhafiz1: Masuk kedalam Kaabah adalah pel...
# 97    azrylzul16  RT @abuhafiz1: Masuk kedalam Kaabah adalah pel...
# 98         zvvko  RT @abuhafiz1: Masuk kedalam Kaabah adalah pel...
# 99    maizatulmr  RT @abuhafiz1: Masuk kedalam Kaabah adalah pel...
#
# [100 rows x 2 columns]

# %% [markdown]
# #### 7. Keyword Syiah Masih Islam

# %%
since_date = datetime.strptime('2023-03-19', '%Y-%m-%d')

last_tweet7 = api.search_tweets(q='syiah masih islam', lang='id', count=1, until='2023-03-28')
last_tweet_id7 = last_tweet7[0].id if len(last_tweet7) > 0 else None
twit7 = api.search_tweets(q='syiah masih islam', lang='id', count=100, since_id=last_tweet_id7)

hasilSearch7 = twit7
hasilSearch = hasilSearch7
hasilAnalisis = []


for tweet in hasilSearch:
    tweet_properties = {}
    tweet_properties['pengguna'] = tweet.user.screen_name
    tweet_properties['tweet'] = tweet.text
    tweet_bersih =' ' .join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", tweet.text).split())
    hasilAnalisis.append(tweet_properties)

pengguna=[]
tweet=[]


for i in range (0,len (hasilAnalisis)):
    pengguna.append (hasilAnalisis [i]['pengguna'])
    tweet.append(hasilAnalisis[i]['tweet'])

maret_syiah_masih_islam = pd.DataFrame({'pengguna' :pengguna, 'tweet': tweet})

# %%
maret_syiah_masih_islam
# Out:
# Empty DataFrame
# Columns: [pengguna, tweet]
# Index: []

# %%
# writing to Excel
datatoexcel1 = pd.ExcelWriter('Data Crawling Syiah.xlsx')
datatoexcel2 = pd.ExcelWriter('Data Crawling Syiah Indonesia.xlsx')
datatoexcel3 = pd.ExcelWriter('Data Crawling Kafir.xlsx')
datatoexcel4 = pd.ExcelWriter('Data Crawling Sesat.xlsx')
datatoexcel5 = pd.ExcelWriter('Data Crawling Diluar Islam.xlsx')
datatoexcel6 = pd.ExcelWriter('Data Crawling Islam.xlsx')
datatoexcel7 = pd.ExcelWriter('Data Crawling Masih Islam.xlsx')

# write DataFrame to excel
maret_syiah.to_excel(datatoexcel1)
maret_syiah_indonesia.to_excel(datatoexcel2)
maret_syiah_kafir.to_excel(datatoexcel3)
maret_syiah_sesat.to_excel(datatoexcel4)
maret_syiah_diluar_islam.to_excel(datatoexcel5)
maret_syiah_islam.to_excel(datatoexcel6)
maret_syiah_masih_islam.to_excel(datatoexcel7)

# save the excel
datatoexcel1.save()
datatoexcel2.save()
datatoexcel3.save()
datatoexcel4.save()
datatoexcel5.save()
datatoexcel6.save()
datatoexcel7.save()
